# %% [markdown]
# ## Web scraping and analysis
#
# We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# ### Scraping data from Skytrax
#
# If you visit [https://www.airlinequality.com] you can see that there is a lot of data there. For this task, we are only interested in reviews related to British Airways and the Airline itself.
#
# If you navigate to this link: [https://www.airlinequality.com/airline-reviews/british-airways] you will see this data. Now, we can use `Python` and `BeautifulSoup` to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 10
page_size = 100

reviews_data = []
for i in range(1,pages+1):
    print(f"Scraping page {i}")

    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content,'lxml')

    # loop thru all reviews on the page 
    for review in soup.find_all("article", {"itemprop": "review"}):
        review_data = {}

        #Extract revieww title
        review_data['Review_Title'] = review.find("h2").get_text(strip=True) if review.find("h2") else None

        #Extract review date
        review_data['Review_Date'] = review.find("time").get_text(strip=True) if review.find("time") else None

        #Extract type of traveler
        type_traveller_header = review.find("td",class_='review-rating-header type_of_traveller')
        review_data['Type_of_Traveller'] = type_traveller_header.find_next_sibling("td").get_text(strip=True) if type_traveller_header else None

        #Extract seat type 
        review_data['Seat_Type'] = review.find("td", string='Seat Type').find_next_sibling("td").get_text(strip=True) if review.find("td",string='Seat Type') else None

        #Extract route
        review_data['Route'] = review.find("td",string="Route").find_next_sibling("td").get_text(strip=True) if review.find("td",string='Route') else None

        #Extract date flown
        review_data['Date_Flown'] = review.find("td",string="Date Flown").find_next_sibling("td").get_text(strip=True) if review.find("td",string='Date Flown') else None

        #Extract ratings (convert stars to numerica values)
        def extract_rating(category):
            rating_element = review.find("td",string=category)
            if rating_element:
                stars =rating_element.find_next_sibling("td").find_all("span", class_="star fill")
                return len(stars)
            return None

        review_data["Seat_Comfort"] = extract_rating("Seat Comfort")
        review_data["Cabin_Staff_Service"] = extract_rating("Cabin Staff Service")
        review_data["Ground_Service"] = extract_rating("Ground Service")
        review_data["Value_For_Money"] = extract_rating("Value For Money")

        #Extract recommended (convert to 0 or 1)
        recommended = review.find("td",string="Recommended")
        if recommended:
            review_data["Recommended"] = 1 if recommended.find_next_sibling("td").get_text(strip=True) == "yes" else 0
        else:
            review_data['Recommended'] = None

        #Append review data to list 
        reviews_data.append(review_data)

    print(f"   ---> {len(reviews_data)} total reviews scraped")
# Out:
# Scraping page 1
#    ---> 100 total reviews scraped
# Scraping page 2
#    ---> 200 total reviews scraped
# Scraping page 3
#    ---> 300 total reviews scraped
# Scraping page 4
#    ---> 400 total reviews scraped
# Scraping page 5
#    ---> 500 total reviews scraped
# Scraping page 6
#    ---> 600 total reviews scraped
# Scraping page 7
#    ---> 700 total reviews scraped
# Scraping page 8
#    ---> 800 total reviews scraped
# Scraping page 9
#    ---> 900 total reviews scraped
# Scraping page 10
#    ---> 1000 total reviews scraped

# %%
#Convert to DataFrame
BA_df = pd.DataFrame(reviews_data)

#Save to CSV 
BA_df.to_csv("BA_reviews1.csv",index=False)
print("CSV file saved successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Convert to DataFrame
# ----> 2 BA_df = pd.DataFrame(reviews_data)
#       4 #Save to CSV
#       5 BA_df.to_csv("BA_reviews1.csv",index=False)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Congratulations! Now you have your dataset for this task! The loops above collected 1000 reviews by iterating through the paginated pages on the website. However, if you want to collect more data, try increasing the number of pages!
#
#  The next thing that you should do is clean this data to remove any unnecessary text from each of the rows. For example, "✅ Trip Verified" can be removed from each row if it exists, as it's not relevant to what we want to investigate.

# %%
test = pd.read_csv('BA_reviews.csv')

# %%
test
# Out:
#                              Review_Title          Review_Date  \
# 0         "disagreeable flight attendant"      19th March 2025
# 1      "flight was delayed nearly 1 hour"      16th March 2025
# 2                "full of attitude to me"      16th March 2025
# 3                "service was outrageous"      16th March 2025
# 4       "managed to get everything right"       7th March 2025
# ..                                    ...                  ...
# 995  "welcome wasn’t especially friendly"  10th September 2019
# 996         "been upgraded to Club World"   8th September 2019
# 997      "standards on BA have plummeted"   7th September 2019
# 998                   "Good value flight"   6th September 2019
# 999                 "not worth the money"   6th September 2019
#
#     Type_of_Traveller        Seat_Type                         Route  \
# 0        Solo Leisure   Business Class           Cape Town to London
# 1            Business   Business Class              London to Geneva
# 2            Business  Premium Economy            London to New York
# 3            Business   Business Class            Chambery to London
# 4            Business  Premium Economy            Gatwick to Antigua
# ..                ...              ...                           ...
# 995      Solo Leisure   Business Class  Mahe to Stockholm via London
# 996    Couple Leisure   Business Class  Glasgow to Tampa via Gatwick
# 997    Family Leisure    Economy Class            Orlando to Gatwick
# 998    Family Leisure    Economy Class           London to Abu Dhabi
# 999    Couple Leisure   Business Class      London to St Petersburgh
#
#          Date_Flown  Seat_Comfort  Cabin_Staff_Service  Ground_Service  \
# 0        March 2025           5.0                  2.0             4.0
# 1     December 2024           1.0                  1.0             1.0
# 2      January 2025           1.0                  1.0             5.0
# 3      January 2025           1.0                  1.0             1.0
# 4        March 2025           5.0                  5.0             5.0
# ..              ...           ...                  ...             ...
# 995  September 2019           1.0                  2.0             1.0
# 996  September 2019           4.0                  5.0             5.0
# 997  September 2019           2.0                  3.0             3.0
# 998     August 2019           3.0                  4.0             4.0
# 999     August 2019           1.0                  3.0             5.0
#
#      Value_For_Money  Recommended
# 0                  4            1
# 1                  1            0
# 2                  1            0
# 3                  1            0
# 4                  5            1
# ..               ...          ...
# 995                2            0
# 996                4            1
# 997                1            0
# 998                4            1
# 999                1            0
#
# [1000 rows x 11 columns]

# %%
test[test['Recommended'] == 1 ]
# Out:
#                           Review_Title          Review_Date Type_of_Traveller  \
# 0      "disagreeable flight attendant"      19th March 2025      Solo Leisure
# 4    "managed to get everything right"       7th March 2025          Business
# 5           "The seats were excellent"   28th February 2025    Couple Leisure
# 10    "thoroughly enjoyed this flight"   14th February 2025      Solo Leisure
# 12     "a really enjoyable experience"    1st February 2025    Couple Leisure
# ..                                 ...                  ...               ...
# 981          "the value was very good"  21st September 2019      Solo Leisure
# 992   "inflight service was top notch"  12th September 2019    Couple Leisure
# 993          "Still recommended by me"  11th September 2019    Couple Leisure
# 996      "been upgraded to Club World"   8th September 2019    Couple Leisure
# 998                "Good value flight"   6th September 2019    Family Leisure
#
#            Seat_Type                                Route      Date_Flown  \
# 0     Business Class                  Cape Town to London      March 2025
# 4    Premium Economy                   Gatwick to Antigua      March 2025
# 5    Premium Economy                     Mumbai to London   February 2025
# 10     Economy Class             Dubai to London Heathrow   February 2025
# 12    Business Class                       London to Male    January 2025
# ..               ...                                  ...             ...
# 981    Economy Class      London Heathrow to Berlin Tegel  September 2019
# 992   Business Class  Belfast to San Francisco via London     August 2019
# 993    Economy Class                 London to Gothenburg  September 2019
# 996   Business Class         Glasgow to Tampa via Gatwick  September 2019
# 998    Economy Class                  London to Abu Dhabi     August 2019
#
#      Seat_Comfort  Cabin_Staff_Service  Ground_Service  Value_For_Money  \
# 0             5.0                  2.0             4.0                4
# 4             5.0                  5.0             5.0                5
# 5             5.0                  4.0             4.0                5
# 10            4.0                  5.0             5.0                5
# 12            5.0                  5.0             5.0                4
# ..            ...                  ...             ...              ...
# 981           5.0                  5.0             3.0                5
# 992           5.0                  5.0             5.0                5
# 993           4.0                  4.0             4.0                4
# 996           4.0                  5.0             5.0                4
# 998           3.0                  4.0             4.0                4
#
#      Recommended
# 0              1
# 4              1
# 5              1
# 10             1
# 12             1
# ..           ...
# 981            1
# 992            1
# 993            1
# 996            1
# 998            1
#
# [312 rows x 11 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         1000 non-null   object
#  1   Review_Date          1000 non-null   object
#  2   Type_of_Traveller    998 non-null    object
#  3   Seat_Type            1000 non-null   object
#  4   Route                996 non-null    object
#  5   Date_Flown           1000 non-null   object
#  6   Seat_Comfort         913 non-null    float64
#  7   Cabin_Staff_Service  903 non-null    float64
#  8   Ground_Service       944 non-null    float64
#  9   Value_For_Money      1000 non-null   int64
#  10  Recommended          1000 non-null   int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 86.1+ KB

# %%
test[test['Type_of_Traveller'].isnull()]
# Out:
#                                    Review_Title         Review_Date  \
# 286  "British Airways absolutely does not care"  1st September 2023
# 564              "become an absolute nightmare"      13th July 2022
#
#     Type_of_Traveller       Seat_Type                  Route   Date_Flown  \
# 286               NaN   Economy Class  Los Angeles to London  August 2023
# 564               NaN  Business Class       London to Malaga    July 2022
#
#      Seat_Comfort  Cabin_Staff_Service  Ground_Service  Value_For_Money  \
# 286           1.0                  1.0             1.0                1
# 564           NaN                  NaN             NaN                1
#
#      Recommended
# 286            0
# 564            0

# %%
test.loc[564]
# Out:
# Review_Title           "become an absolute nightmare"
# Review_Date                            13th July 2022
# Type_of_Traveller                                 NaN
# Seat_Type                              Business Class
# Route                                London to Malaga
# Date_Flown                                  July 2022
# Seat_Comfort                                      NaN
# Cabin_Staff_Service                               NaN
# Ground_Service                                    NaN
# Value_For_Money                                     1
# Recommended                                         0
# Name: 564, dtype: object

# %%
test.drop(index=564,inplace=True)

# %%
test.head(2)
# Out:
#                          Review_Title      Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  19th March 2025      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  16th March 2025          Business
#
#         Seat_Type                Route     Date_Flown  Seat_Comfort  \
# 0  Business Class  Cape Town to London     March 2025           5.0
# 1  Business Class     London to Geneva  December 2024           1.0
#
#    Cabin_Staff_Service  Ground_Service  Value_For_Money  Recommended
# 0                  2.0             4.0                4            1
# 1                  1.0             1.0                1            0

# %%
test['Value_For_Money'].value_counts()
# Out:
# Value_For_Money
# 1    460
# 4    143
# 3    140
# 2    140
# 5    116
# Name: count, dtype: int64

# %% [markdown]
# ## Summary of this dataset
#
# British Airways (BA) is the flag carrier airline of the United Kingdom (UK). Every day, thousands of BA flights arrive to and depart from the UK, carrying customers across the world. Whether it’s for holidays, work or any other reason, the end-to-end process of scheduling, planning, boarding, fuelling, transporting, landing, and continuously running flights on time, efficiently and with top-class customer service is a huge task with many highly important responsibilities
#
# This dataset contains the information of the customers who left a review on the service of British Airways

# %% [markdown]
# ### Column descriptions
#
# #### Table -> `test`
#
# * `Review_Title`: The review title written by each customer which conveys the main/major issue or their views on customer service at British Airways.
# * `Review_Date`: The date when the customer wrote the review on services.
# * `Type_of_Traveller`: There are 4 types of travellers using BA, like Couple Leisure, Solo Leisure, Business, Family Leisure.
# * `Seat_Type`: There are 4 types of Seat Types, i.e Economy Class, Business Class, Premium Economy, First Class
# * `Route`: This column tells us the route taken by the customer for their respective reviews given for that flight.
# * `Date_Flown`: The date when the customer had his/her flight date.
# * `Seat_Comfort`: This column tells the rating out of 5, given by the customer on comfort level of the seat.
# * `Cabin_Staff_Service`: This col tells the rating(out of 5) for the cabin staff service of that particular flight.
# * `Ground_Service`: Rating(out of 5) for the ground services at the airport. These services include loading and unloading baggage and cargo, aircraft maintenance, and passenger services.
# * `Value_For_Money`: Rating(out of 5) tells if the customer thinks the BA flight is value for money or not.
# * `Recommended`: This col tells if the customer recommends the services of BA or not(represented by 0 for 'Not Recommened' and 1 for 'Recommended'.)

# %% [markdown]
# ### Issues with Dataset
#
# #### 1.Dirty Data
#
# `test`:
# * null values in Type_of_Traveller, Route, Seat_Comfort, Cabin_Staff_Service, Ground_Service columns
# * there are 204 NaT values in Review_Date col but i am gonnna ignore it for now and see if it contributes to any analysis if it doesnt i will drop the col.

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         999 non-null    object
#  1   Review_Date          999 non-null    object
#  2   Type_of_Traveller    998 non-null    object
#  3   Seat_Type            999 non-null    object
#  4   Route                995 non-null    object
#  5   Date_Flown           999 non-null    object
#  6   Seat_Comfort         913 non-null    float64
#  7   Cabin_Staff_Service  903 non-null    float64
#  8   Ground_Service       944 non-null    float64
#  9   Value_For_Money      999 non-null    int64
#  10  Recommended          999 non-null    int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 93.7+ KB

# %%
test[test.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Review_Title, Review_Date, Type_of_Traveller, Seat_Type, Route, Date_Flown, Seat_Comfort, Cabin_Staff_Service, Ground_Service, Value_For_Money, Recommended]
# Index: []

# %%
test.describe()
# Out:
#        Seat_Comfort  Cabin_Staff_Service  Ground_Service  Value_For_Money  \
# count    913.000000           903.000000      944.000000       999.000000
# mean       2.714129             3.106312        2.490466         2.314314
# std        1.386965             1.526482        1.532924         1.456554
# min        1.000000             1.000000        1.000000         1.000000
# 25%        1.000000             2.000000        1.000000         1.000000
# 50%        3.000000             3.000000        2.000000         2.000000
# 75%        4.000000             5.000000        4.000000         4.000000
# max        5.000000             5.000000        5.000000         5.000000
#
#        Recommended
# count   999.000000
# mean      0.312312
# std       0.463669
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
test[test['Type_of_Traveller'].isnull()]
# Out:
#                                    Review_Title         Review_Date  \
# 286  "British Airways absolutely does not care"  1st September 2023
#
#     Type_of_Traveller      Seat_Type                  Route   Date_Flown  \
# 286               NaN  Economy Class  Los Angeles to London  August 2023
#
#      Seat_Comfort  Cabin_Staff_Service  Ground_Service  Value_For_Money  \
# 286           1.0                  1.0             1.0                1
#
#      Recommended
# 286            0

# %%
test.isnull().sum()
# Out:
# Review_Title            0
# Review_Date             0
# Type_of_Traveller       1
# Seat_Type               0
# Route                   4
# Date_Flown              0
# Seat_Comfort           86
# Cabin_Staff_Service    96
# Ground_Service         55
# Value_For_Money         0
# Recommended             0
# dtype: int64

# %%
df = test.copy()

# %%
df.head(2)
# Out:
#                          Review_Title      Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  19th March 2025      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  16th March 2025          Business
#
#         Seat_Type                Route     Date_Flown  Seat_Comfort  \
# 0  Business Class  Cape Town to London     March 2025           5.0
# 1  Business Class     London to Geneva  December 2024           1.0
#
#    Cabin_Staff_Service  Ground_Service  Value_For_Money  Recommended
# 0                  2.0             4.0                4            1
# 1                  1.0             1.0                1            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         999 non-null    object
#  1   Review_Date          999 non-null    object
#  2   Type_of_Traveller    998 non-null    object
#  3   Seat_Type            999 non-null    object
#  4   Route                995 non-null    object
#  5   Date_Flown           999 non-null    object
#  6   Seat_Comfort         913 non-null    float64
#  7   Cabin_Staff_Service  903 non-null    float64
#  8   Ground_Service       944 non-null    float64
#  9   Value_For_Money      999 non-null    int64
#  10  Recommended          999 non-null    int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 93.7+ KB

# %%
df[df['Type_of_Traveller'].isnull()]
# Out:
#                                    Review_Title         Review_Date  \
# 286  "British Airways absolutely does not care"  1st September 2023
#
#     Type_of_Traveller      Seat_Type                  Route   Date_Flown  \
# 286               NaN  Economy Class  Los Angeles to London  August 2023
#
#      Seat_Comfort  Cabin_Staff_Service  Ground_Service  Value_For_Money  \
# 286           1.0                  1.0             1.0                1
#
#      Recommended
# 286            0

# %%
df['Review_Date'] = pd.to_datetime(df['Review_Date'], errors='coerce')
df['Date_Flown'] = pd.to_datetime(df['Date_Flown'], errors='coerce', format="%B %Y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         999 non-null    object
#  1   Review_Date          795 non-null    datetime64[ns]
#  2   Type_of_Traveller    998 non-null    object
#  3   Seat_Type            999 non-null    object
#  4   Route                995 non-null    object
#  5   Date_Flown           999 non-null    datetime64[ns]
#  6   Seat_Comfort         913 non-null    float64
#  7   Cabin_Staff_Service  903 non-null    float64
#  8   Ground_Service       944 non-null    float64
#  9   Value_For_Money      999 non-null    int64
#  10  Recommended          999 non-null    int64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(4)
# memory usage: 93.7+ KB

# %%
df.loc[286,'Type_of_Traveller'] = 'Unknown'

# %%
df.loc[286]
# Out:
# Review_Title           "British Airways absolutely does not care"
# Review_Date                                                   NaT
# Type_of_Traveller                                         Unknown
# Seat_Type                                           Economy Class
# Route                                       Los Angeles to London
# Date_Flown                                    2023-08-01 00:00:00
# Seat_Comfort                                                  1.0
# Cabin_Staff_Service                                           1.0
# Ground_Service                                                1.0
# Value_For_Money                                                 1
# Recommended                                                     0
# Name: 286, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         999 non-null    object
#  1   Review_Date          795 non-null    datetime64[ns]
#  2   Type_of_Traveller    999 non-null    object
#  3   Seat_Type            999 non-null    object
#  4   Route                995 non-null    object
#  5   Date_Flown           999 non-null    datetime64[ns]
#  6   Seat_Comfort         913 non-null    float64
#  7   Cabin_Staff_Service  903 non-null    float64
#  8   Ground_Service       944 non-null    float64
#  9   Value_For_Money      999 non-null    int64
#  10  Recommended          999 non-null    int64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(4)
# memory usage: 125.9+ KB

# %%
df.fillna(df[['Seat_Comfort','Cabin_Staff_Service','Ground_Service']].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Review_Title             0
# Review_Date            204
# Type_of_Traveller        0
# Seat_Type                0
# Route                    4
# Date_Flown               0
# Seat_Comfort             0
# Cabin_Staff_Service      0
# Ground_Service           0
# Value_For_Money          0
# Recommended              0
# dtype: int64

# %%
df[['Seat_Comfort','Cabin_Staff_Service','Ground_Service']] = df[['Seat_Comfort','Cabin_Staff_Service','Ground_Service']].astype(int)

# %%
df['Route'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Aabhas\AppData\Local\Temp\ipykernel_16036\3339572337.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Route'].fillna('Unknown',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         999 non-null    object
#  1   Review_Date          795 non-null    datetime64[ns]
#  2   Type_of_Traveller    999 non-null    object
#  3   Seat_Type            999 non-null    object
#  4   Route                999 non-null    object
#  5   Date_Flown           999 non-null    datetime64[ns]
#  6   Seat_Comfort         999 non-null    int64
#  7   Cabin_Staff_Service  999 non-null    int64
#  8   Ground_Service       999 non-null    int64
#  9   Value_For_Money      999 non-null    int64
#  10  Recommended          999 non-null    int64
# dtypes: datetime64[ns](2), int64(5), object(4)
# memory usage: 125.9+ KB

# %%
df['overall_rating'] = df[['Seat_Comfort','Cabin_Staff_Service','Ground_Service','Value_For_Money']].apply(lambda x: (x.sum()/20)*10,axis=1).astype(int)

# %% [markdown]
# ## DEFINE
#
# * CLeaned all the null values from the dataset except Review_Date NaT values
# * Replaced the one NaN value in the Type_of_Traveller column to unknown
# * Filled all the null values in Seat_Comfort, Cabin_Staff_Service, Ground_Service with their median values
# * Converted the columns: Seat_Comfort, Cabin_Staff_Service, Ground_Service dtypes from float to int

# %% [markdown]
# ### Column Types
#
# * `Numerical`:
# * `Categorical`: Type_of_Traveller, Seat_Type, Seat_Comfort, Cabin_Staff_Service, Ground_Service, Value_For_Money, Recommended

# %%
df.head(2)
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
#
#         Seat_Type                Route Date_Flown  Seat_Comfort  \
# 0  Business Class  Cape Town to London 2025-03-01             5
# 1  Business Class     London to Geneva 2024-12-01             1
#
#    Cabin_Staff_Service  Ground_Service  Value_For_Money  Recommended  \
# 0                    2               4                4            1
# 1                    1               1                1            0
#
#    overall_rating
# 0               7
# 1               2

# %% [markdown]
# ## EDA
#
# ### Univariate Analysis

# %%
df.describe()
# Out:
#                          Review_Date                     Date_Flown  \
# count                            795                            999
# mean   2022-07-07 17:01:35.094339584  2022-06-17 00:38:55.135134976
# min              2019-09-06 00:00:00            2019-04-01 00:00:00
# 25%              2021-07-16 12:00:00            2021-07-01 00:00:00
# 50%              2022-11-07 00:00:00            2022-11-01 00:00:00
# 75%              2023-10-02 12:00:00            2023-09-01 00:00:00
# max              2025-03-19 00:00:00            2025-03-01 00:00:00
# std                              NaN                            NaN
#
#        Seat_Comfort  Cabin_Staff_Service  Ground_Service  Value_For_Money  \
# count    999.000000           999.000000      999.000000       999.000000
# mean       2.738739             3.096096        2.463463         2.314314
# min        1.000000             1.000000        1.000000         1.000000
# 25%        1.000000             2.000000        1.000000         1.000000
# 50%        3.000000             3.000000        2.000000         2.000000
# 75%        4.000000             4.000000        4.000000         4.000000
# max        5.000000             5.000000        5.000000         5.000000
# std        1.328284             1.451547        1.494283         1.456554
#
#        Recommended  overall_rating
# count   999.000000      999.000000
# mean      0.312312        5.090090
# min       0.000000        2.000000
# 25%       0.000000        3.000000
# 50%       0.000000        5.000000
# 75%       1.000000        7.000000
# max       1.000000       10.000000
# std       0.463669        2.396953

# %%
df['Recommended'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Recommended'>

# %%
df['Recommended'].value_counts().plot(kind='pie', autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
for col in ["Type_of_Traveller", "Seat_Type", "Recommended"]:
    print(f"\n{col}:\n", df[col].value_counts())
# Out:
# Type_of_Traveller:
#  Type_of_Traveller
# Couple Leisure    338
# Solo Leisure      323
# Business          178
# Family Leisure    159
# Unknown             1
# Name: count, dtype: int64
#
# Seat_Type:
#  Seat_Type
# Economy Class      550
# Business Class     345
# Premium Economy     86
# First Class         18
# Name: count, dtype: int64
#
# Recommended:
#  Recommended
# 0    687
# 1    312
# Name: count, dtype: int64

# %%
df['Type_of_Traveller'].value_counts().plot(kind='pie', autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['Type_of_Traveller'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type_of_Traveller'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['Type_of_Traveller'],hue=df['Type_of_Traveller'] ,palette='pastel', edgecolor='black')
plt.title('Distribution of Traveller Types',fontsize=16,fontweight='bold')
plt.xlabel('Traveller Type',fontsize=14)
plt.ylabel('Count',fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.grid(axis='y', linestyle='--',alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12,6))
ax = sns.countplot(x=df['Seat_Type'], palette='Set2', edgecolor="black",hue=df['Seat_Type'])
plt.title('Distribution of Seat Types', fontsize=16, fontweight='bold')
plt.xlabel("Seat Type", fontsize=14)
plt.ylabel("Count", fontsize=14)

# Adding value labels on top of bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')

plt.show()

# %%
rating_cols = ['Seat_Comfort','Cabin_Staff_Service','Ground_Service','Value_For_Money']
plt.figure(figsize=(12,8))
for i,col in enumerate(rating_cols):
    plt.subplot(2,2,i+1)
    sns.countplot(f"Distribution of {col}")
plt.show()

# %%
df.head()
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
# 2            "full of attitude to me"  2025-03-16          Business
# 3            "service was outrageous"  2025-03-16          Business
# 4   "managed to get everything right"  2025-03-07          Business
#
#          Seat_Type                Route Date_Flown  Seat_Comfort  \
# 0   Business Class  Cape Town to London 2025-03-01             5
# 1   Business Class     London to Geneva 2024-12-01             1
# 2  Premium Economy   London to New York 2025-01-01             1
# 3   Business Class   Chambery to London 2025-01-01             1
# 4  Premium Economy   Gatwick to Antigua 2025-03-01             5
#
#    Cabin_Staff_Service  Ground_Service  Value_For_Money  Recommended  \
# 0                    2               4                4            1
# 1                    1               1                1            0
# 2                    1               5                1            0
# 3                    1               1                1            0
# 4                    5               5                5            1
#
#    overall_rating
# 0               7
# 1               2
# 2               4
# 3               2
# 4              10

# %%
df['Seat_Comfort'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Seat_Comfort'>

# %%
recommendation_rate = df.groupby("overall_rating")['Recommended'].mean()*100

# %%
recommendation_rate
# Out:
# overall_rating
# 2       0.000000
# 3       0.675676
# 4       1.010101
# 5      10.236220
# 6      40.229885
# 7      73.611111
# 8      96.511628
# 9      96.511628
# 10    100.000000
# Name: Recommended, dtype: float64

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
sns.lineplot(x=recommendation_rate.index, y=recommendation_rate.values,
            marker='o', linestyle='-', color='b', linewidth=2)
plt.xlabel('Overall Rating', fontsize=14)
plt.ylabel('Recommendation Rate (%)',fontsize=14)
plt.title("Do Higher Ratings lead to more Recommendations?",fontsize=16,fontweight='bold')
plt.grid(True, linestyle='--',alpha=0.6)
plt.show()

# %%
df_filtered = df[df['Seat_Type'].isin(['Economy Class','Business Class'])]
sns.set_style('whitegrid')
plt.figure(figsize=(8,5))
sns.boxplot(
    x = 'Seat_Type',
    y = 'overall_rating',
    data = df_filtered,
    hue='Seat_Type',
    palette='Set2',
    width=0.5,
    linewidth=2,
    showmeans=True,
    meanprops = {'marker':'o','markerfacecolor':'black','markeredgecolor':'white','markersize':'8'}
)

plt.xlabel('Seat Type',fontsize=14,fontweight='bold')
plt.ylabel('Overall Rating',fontsize=14,fontweight='bold')
plt.title("Comparision of Satisfaction: Economy vs Business Class",fontsize=16,fontweight='bold')
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()

avg_ratings = df_filtered.groupby('Seat_Type')['overall_rating'].mean()
avg_ratings
# Out:
# Seat_Type
# Business Class    5.594752
# Economy Class     4.695971
# Name: overall_rating, dtype: float64

# %%
df.groupby('Seat_Type',observed=False)[['overall_rating']].describe()
# Out:
#                 overall_rating
#                          count      mean       std  min  25%  50%  75%   max
# Seat_Type
# Business Class           345.0  5.582609  2.423178  2.0  4.0  5.0  8.0  10.0
# Economy Class            550.0  4.692727  2.313763  2.0  3.0  4.0  6.0  10.0
# First Class               18.0  6.500000  2.431412  2.0  5.0  6.0  9.0  10.0
# Premium Economy           86.0  5.360465  2.330932  2.0  4.0  5.0  7.0  10.0

# %% [markdown]
# ### Here we can clearly see that the people who travelled the business class had a greater level of satisfaction compared to people who traveled by Economy Class.

# %%
test['Route'].value_counts()
# Out:
# Route
# Vancouver to London                      12
# London to Hong Kong                       8
# San Francisco to London                   8
# Johannesburg to London                    7
# Singapore to London                       7
#                                          ..
# Nairobi to London                         1
# Berlin to London Heathrow                 1
# London Heathrow to Abuja Nigeria          1
# Hyderabad to San Francisco via London     1
# Toulouse to London                        1
# Name: count, Length: 646, dtype: int64

# %%
df['Route'].str.contains(' to ', na=False).value_counts()
# Out:
# Route
# True     993
# False      6
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Review_Title         999 non-null    object
#  1   Review_Date          795 non-null    datetime64[ns]
#  2   Type_of_Traveller    999 non-null    object
#  3   Seat_Type            999 non-null    object
#  4   Route                999 non-null    object
#  5   Date_Flown           999 non-null    datetime64[ns]
#  6   Seat_Comfort         999 non-null    int64
#  7   Cabin_Staff_Service  999 non-null    int64
#  8   Ground_Service       999 non-null    int64
#  9   Value_For_Money      999 non-null    int64
#  10  Recommended          999 non-null    int64
#  11  overall_rating       999 non-null    int64
# dtypes: datetime64[ns](2), int64(6), object(4)
# memory usage: 133.8+ KB

# %%
df = df[df['Route'].str.contains(' to ',na=False)]

# %%
df.head(2)
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
#
#         Seat_Type                Route Date_Flown  Seat_Comfort  \
# 0  Business Class  Cape Town to London 2025-03-01             5
# 1  Business Class     London to Geneva 2024-12-01             1
#
#    Cabin_Staff_Service  Ground_Service  Value_For_Money  Recommended  \
# 0                    2               4                4            1
# 1                    1               1                1            0
#
#    overall_rating
# 0               7
# 1               2

# %%
df.groupby('Type_of_Traveller',observed=False)['overall_rating'].describe()
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# Type_of_Traveller
# Business           178.0  4.544944  2.061403  2.0  3.0  4.0  5.0  10.0
# Couple Leisure     336.0  5.211310  2.334681  2.0  3.0  5.0  7.0  10.0
# Family Leisure     156.0  4.692308  2.413979  2.0  3.0  4.0  7.0  10.0
# Solo Leisure       322.0  5.487578  2.545811  2.0  3.0  5.0  8.0  10.0
# Unknown              1.0  2.000000       NaN  2.0  2.0  2.0  2.0   2.0

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df['Type_of_Traveller'].value_counts().index,
           y=df['Type_of_Traveller'].value_counts().values,
           hue=df['Type_of_Traveller'].value_counts().index,
           palette = 'Set2', edgecolor='black')

plt.xlabel('Type of Traveller',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title("Distribution of Travellers by Type",fontsize=14,fontweight='bold')
plt.xticks(rotation=45,ha='right')
plt.grid(axis='y',linestyle='--', alpha=0.7)
plt.show()

# %%
df.head(2)
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
#
#         Seat_Type                Route Date_Flown  Seat_Comfort  \
# 0  Business Class  Cape Town to London 2025-03-01             5
# 1  Business Class     London to Geneva 2024-12-01             1
#
#    Cabin_Staff_Service  Ground_Service  Value_For_Money  Recommended  \
# 0                    2               4                4            1
# 1                    1               1                1            0
#
#    overall_rating
# 0               7
# 1               2

# %%
pd.crosstab(df['Type_of_Traveller'],df['Date_Flown'],normalize='columns')*100
# Out:
# Date_Flown         2019-04-01  2019-07-01  2019-08-01  2019-09-01  2019-10-01  \
# Type_of_Traveller
# Business                  0.0         0.0         0.0      12.500   25.000000
# Couple Leisure          100.0         0.0        50.0      59.375   38.888889
# Family Leisure            0.0        50.0        50.0       3.125    8.333333
# Solo Leisure              0.0        50.0         0.0      25.000   27.777778
# Unknown                   0.0         0.0         0.0       0.000    0.000000
#
# Date_Flown         2019-11-01  2019-12-01  2020-01-01  2020-02-01  2020-03-01  \
# Type_of_Traveller
# Business            25.806452    8.333333   22.580645   22.222222   21.052632
# Couple Leisure      25.806452   25.000000   32.258065   44.444444   36.842105
# Family Leisure      16.129032   16.666667   12.903226    0.000000    5.263158
# Solo Leisure        32.258065   50.000000   32.258065   33.333333   36.842105
# Unknown              0.000000    0.000000    0.000000    0.000000    0.000000
#
# Date_Flown         ...  2024-06-01  2024-07-01  2024-08-01  2024-09-01  \
# Type_of_Traveller  ...
# Business           ...   16.666667    9.090909   25.000000   15.384615
# Couple Leisure     ...   33.333333   36.363636    4.166667   38.461538
# Family Leisure     ...    0.000000   27.272727   29.166667   15.384615
# Solo Leisure       ...   50.000000   27.272727   41.666667   30.769231
# Unknown            ...    0.000000    0.000000    0.000000    0.000000
#
# Date_Flown         2024-10-01  2024-11-01  2024-12-01  2025-01-01  2025-02-01  \
# Type_of_Traveller
# Business            20.000000    9.090909        25.0   42.857143         0.0
# Couple Leisure      26.666667    9.090909        25.0   14.285714        60.0
# Family Leisure       6.666667   45.454545        12.5   28.571429         0.0
# Solo Leisure        46.666667   36.363636        37.5   14.285714        40.0
# Unknown              0.000000    0.000000         0.0    0.000000         0.0
#
# Date_Flown         2025-03-01
# Type_of_Traveller
# Business                 50.0
# Couple Leisure            0.0
# Family Leisure            0.0
# Solo Leisure             50.0
# Unknown                   0.0
#
# [5 rows x 69 columns]

# %%
cols = ['Seat_Comfort', 'Cabin_Staff_Service', 'Ground_Service', 'Value_For_Money']

for col in cols:
    plt.figure(figsize=(9,5))
    sns.histplot(df[col], bins=5, kde=True, color='royalblue', edgecolor='black', alpha=0.8)
    
    plt.title(f'Distribution of {col}', fontsize=14, fontweight='bold', color='darkblue')
    plt.xlabel(col.replace('_', ' '), fontsize=12)
    plt.ylabel("Frequency", fontsize=12)
    
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()  # Adjusts layout to prevent overlap
    plt.show()

# %%
sns.countplot(x = df['Recommended'])
# Out:
# <Axes: xlabel='Recommended', ylabel='count'>

# %%
plt.figure(figsize=(7, 7))  # Set figure size

# colors = sns.color_palette("Set2")  # Soft pastel colors
df['Type_of_Traveller'].value_counts().plot.pie(
    autopct='%1.1f%%', 
    startangle=90, 
    # colors=colors, 
    wedgeprops={'edgecolor': 'black'},  # Adds a border for clarity
    textprops={'fontsize': 12}  # Increases font size for better readability
)

plt.title("Distribution of Type of Traveller", fontsize=14, fontweight='bold', color='darkblue')
plt.ylabel('')  # Remove y-axis label
plt.show()

# %%
plt.figure(figsize=(7, 5))  # Set figure size

sns.set_style("whitegrid")  # Apply a clean background style
sns.boxplot(x='Recommended', y='overall_rating', data=df, palette="dark:salmon_r", width=0.6, hue='Recommended')

plt.title("Boxplot of Overall Rating vs Recommended", fontsize=14, fontweight='bold', color='brown')
plt.xlabel("Recommended", fontsize=12)
plt.ylabel("Overall Rating", fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.6)  # Add gridlines for better readability
plt.show()

# %%
plt.figure(figsize=(8, 5))  # Set figure size

sns.set_style("whitegrid")  # Apply clean background style
ax = sns.barplot(x='Seat_Type', y='Value_For_Money', data=df, palette="coolwarm", hue='Seat_Type', edgecolor='black')

plt.title("Value for Money by Seat Type", fontsize=14, fontweight='bold', color='darkblue')
plt.xlabel("Seat Type", fontsize=12)
plt.ylabel("Value for Money", fontsize=12)

# Rotate x-axis labels for better readability (if needed)
plt.xticks(rotation=30, ha='right')

# Add data labels on bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}', 
                (p.get_x() + p.get_width() / 2, p.get_height()),  
                ha='center', va='bottom', fontsize=10, color='black', fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(7, 5))  # Set figure size

sns.set_style("whitegrid")  # Apply a clean background style
sns.boxplot(x='Seat_Type', y='overall_rating', data=df, palette="pastel", width=0.6, hue='Seat_Type')

plt.title("Boxplot of Overall Rating vs Seat Types", fontsize=14, fontweight='bold', color='brown')
plt.xlabel("Seat Types", fontsize=12)
plt.ylabel("Overall Rating", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)  # Add gridlines for better readability

plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set_style("white")
heatmap = sns.heatmap(df[['Seat_Comfort', 'Cabin_Staff_Service', 'Ground_Service', 'Value_For_Money', 'overall_rating']].corr(),
                     annot=True,cmap='coolwarm',linewidth=0.5, linecolor='black',
                     square=True, cbar_kws = {'shrink': 0.8}, annot_kws={'size':10,'color':'black'})

plt.title('Correlation Heatmap', fontsize=14, fontweight='bold',color='darkred')
plt.xticks(rotation=30, ha='right',fontsize=10)
plt.yticks(rotation=10)
plt.show()

# %%
df[['Departure_City','Arrival_City']] = df['Route'].str.split(' to ',expand=True).drop(2,axis=1)

# %%
plt.figure(figsize=(10, 5))  # Increase figure size for clarity
sns.set_style("whitegrid")  # Use a clean background style

# Plot the top 10 departure cities as a bar chart
df['Departure_City'].value_counts().nlargest(10).plot(kind='bar', 
                                                       color='royalblue', 
                                                       edgecolor='black', 
                                                       alpha=0.8)

# Improve labels and title
plt.title("Top 10 Departure Cities", fontsize=14, fontweight='bold', color='darkred')
plt.xlabel("Departure City", fontsize=12)
plt.ylabel("Number of Flights", fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right", fontsize=10)

# Add gridlines for better visualization
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
cross = pd.crosstab(df['Seat_Type'],df['Recommended'])

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cross, annot=True, fmt='d', cmap='coolwarm')
plt.title('Seat Type vs Recommendation', fontsize=14, fontweight='bold', color='darkred')
plt.xlabel('Recommendation',fontsize=12)
plt.ylabel('Seat Type', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style('whitegrid')
cross.plot(kind='bar', stacked=True, figsize=(10,6), cmap='viridis', edgecolor='black', alpha=0.9)
plt.title("Seat Type vs Recommendation", fontsize=14,fontweight='bold',color='darkblue')
plt.xlabel('Seat Type',fontsize=12)
plt.ylabel('Count',fontsize=12)

plt.xticks(rotation=360, ha='right', fontsize=10)

plt.legend(title='Recommended',loc='upper right', fontsize=10)
plt.grid(axis='y',linestyle='--', alpha=0.7)
plt.show()

# %%
df.groupby('Departure_City',observed=False)['Recommended'].describe().sort_values(by='count',ascending=False)
# Out:
#                    count      mean       std  min  25%  50%   75%  max
# Departure_City
# London             271.0  0.317343  0.466303  0.0  0.0  0.0  1.00  1.0
# London Heathrow     95.0  0.357895  0.481924  0.0  0.0  0.0  1.00  1.0
# Gatwick             28.0  0.321429  0.475595  0.0  0.0  0.0  1.00  1.0
# Heathrow            22.0  0.272727  0.455842  0.0  0.0  0.0  0.75  1.0
# Vancouver           19.0  0.526316  0.512989  0.0  0.0  1.0  1.00  1.0
# ...                  ...       ...       ...  ...  ...  ...   ...  ...
# Washington DC        1.0  0.000000       NaN  0.0  0.0  0.0  0.00  0.0
# Zagreb               1.0  0.000000       NaN  0.0  0.0  0.0  0.00  0.0
# Washington Dulles    1.0  0.000000       NaN  0.0  0.0  0.0  0.00  0.0
# doha                 1.0  1.000000       NaN  1.0  1.0  1.0  1.00  1.0
# İstanbul             1.0  0.000000       NaN  0.0  0.0  0.0  0.00  0.0
#
# [187 rows x 8 columns]

# %%
df.drop('Route', axis=1,inplace=True)

# %%
df['Review_Type'] = df['overall_rating'].apply(lambda x: 'Positive' if x>=7 else 'Negative')

# %%
df.head(1)
# Out:
#                       Review_Title Review_Date Type_of_Traveller  \
# 0  "disagreeable flight attendant"  2025-03-19      Solo Leisure
#
#         Seat_Type Date_Flown  Seat_Comfort  Cabin_Staff_Service  \
# 0  Business Class 2025-03-01             5                    2
#
#    Ground_Service  Value_For_Money  Recommended  overall_rating  \
# 0               4                4            1               7
#
#   Departure_City Arrival_City Review_Type
# 0      Cape Town       London    Positive

# %% [markdown]
# ### Q. Do higher-rated reviews lead to more recommendation?

# %%
recommendation_rate = df.groupby('overall_rating',observed=False)['Recommended'].mean()*100

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
sns.lineplot(x=recommendation_rate.index, y=recommendation_rate.values,
            marker='o', linestyle='-', color='b', linewidth=2)
plt.xlabel('Overall Rating', fontsize=14)
plt.ylabel('Recommendation Rate (%)',fontsize=14)
plt.title("Do Higher Ratings lead to more Recommendations?",fontsize=16,fontweight='bold')
plt.grid(True, linestyle='--',alpha=0.6)
plt.show()

# %% [markdown]
# ### Are economy class passengers more dissatisfied than business class?

# %%
plt.figure(figsize=(10, 6))  # Increase figure size for better clarity
sns.set_style("whitegrid")  # Apply clean background style

# Improved Boxplot with pastel colors and better visualization
sns.boxplot(x=df['Seat_Type'], y=df['Seat_Comfort'], palette="pastel", hue=df['Seat_Type'], width=0.6, showmeans=True, 
            meanprops={"marker":"o", "markerfacecolor":"navy", "markeredgecolor":"black", "markersize":"8"})

# Improve title and labels
plt.title("Seat Comfort Ratings by Seat Type", fontsize=14, fontweight='bold', color='darkblue')
plt.xlabel("Seat Type", fontsize=12)
plt.ylabel("Seat Comfort Rating", fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=30, ha="right", fontsize=10)

# Add horizontal gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()

# %%
df.head()
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
# 2            "full of attitude to me"  2025-03-16          Business
# 3            "service was outrageous"  2025-03-16          Business
# 4   "managed to get everything right"  2025-03-07          Business
#
#          Seat_Type Date_Flown  Seat_Comfort  Cabin_Staff_Service  \
# 0   Business Class 2025-03-01             5                    2
# 1   Business Class 2024-12-01             1                    1
# 2  Premium Economy 2025-01-01             1                    1
# 3   Business Class 2025-01-01             1                    1
# 4  Premium Economy 2025-03-01             5                    5
#
#    Ground_Service  Value_For_Money  Recommended  overall_rating  \
# 0               4                4            1               7
# 1               1                1            0               2
# 2               5                1            0               4
# 3               1                1            0               2
# 4               5                5            1              10
#
#   Departure_City Arrival_City Review_Type
# 0      Cape Town       London    Positive
# 1         London       Geneva    Negative
# 2         London     New York    Negative
# 3       Chambery       London    Negative
# 4        Gatwick      Antigua    Positive

# %%
# Compute average overall ratings for the bottom 15 cities
city_ratings = df.groupby('Departure_City', observed=False)['overall_rating'].mean().sort_values().head(15)

# Set figure size and style
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Enhanced Barplot
sns.barplot(
    x=city_ratings.values, 
    y=city_ratings.index,
    hue=city_ratings.index,
    palette='plasma', 
    edgecolor='black'
)

# Improve title and labels
plt.title('Cities with Lowest Average Ratings', fontsize=14, fontweight='bold', color='darkred')
plt.xlabel('Average Overall Ratings', fontsize=12)
plt.ylabel('Departure City', fontsize=12)

# Format x-axis range
plt.xlim(0, 10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Add data labels to bars
for index, value in enumerate(city_ratings.values):
    plt.text(value + 0.2, index, f"{value:.1f}", va='center', fontsize=10, color='black', fontweight='bold')

# Save the figure
plt.savefig('depart.png', dpi=300, bbox_inches='tight') 

plt.show()

# %%
city_ratings
# Out:
# Departure_City
# Dusseldorf           2.0
# Dallas Fort-Worth    2.0
# Delhi                2.0
# Dusseldorf (DUS)     2.0
# Chambery             2.0
# Jeddah               2.0
# Indianapolis         2.0
# Orlando, Florida     2.0
# Paphos               2.0
# Palma de Mallorca    2.0
# Washington DC        2.0
# Washington Dulles    2.0
# Ottawa               2.0
# Marrakech            2.5
# Catania              2.5
# Name: overall_rating, dtype: float64

# %%
a = df[df['Seat_Type'] == 'Economy Class']
b = df[df['Seat_Type'] == 'Business Class']
c = pd.concat([a,b])

# %%
cross = pd.crosstab(c['Seat_Type'],c['overall_rating'])
cross
# Out:
# overall_rating  2   3    4   5   6   7   8   9   10
# Seat_Type
# Business Class  43  42   45  43  41  33  42  41  13
# Economy Class   98  95  128  71  33  30  34  34  23

# %%
plt.figure(figsize=(8,5))
sns.heatmap(cross, annot=True, fmt='d', cmap='coolwarm')
plt.title('Seat Type vs Overall Rating')
plt.show()
plt.savefig('eco.png')

# %%
# %pip install nltk vaderSentiment wordcloud
# Out:
# Requirement already satisfied: nltk in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (3.9.1)
# Requirement already satisfied: vaderSentiment in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (3.3.2)
# Requirement already satisfied: wordcloud in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (1.9.4)
# Requirement already satisfied: click in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: requests in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from wordcloud) (2.2.1)
# Requirement already satisfied: pillow in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: colorama in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from requests->vaderSentiment) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from requests->vaderSentiment) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\aabhas\desktop\sample_project_1\env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import re 
import nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aabhas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aabhas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Aabhas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print(nltk.data.find('tokenizers/punkt'))
# Out:
# C:\Users\Aabhas\AppData\Roaming\nltk_data\tokenizers\punkt

# %% [markdown]
# ## Text Preprocessing

# %%
def clean_text(text):
    text = text.lower() # convert to lowercase
    text = re.sub(r'[^\w\s]','',text) #remove punctuation
    text = " ".join([word for word in word_tokenize(text) if word not in stop_words])
    return text

df['cleaned_review'] = df['Review_Title'].astype(str).apply(clean_text)
df.head()
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
# 2            "full of attitude to me"  2025-03-16          Business
# 3            "service was outrageous"  2025-03-16          Business
# 4   "managed to get everything right"  2025-03-07          Business
#
#          Seat_Type Date_Flown  Seat_Comfort  Cabin_Staff_Service  \
# 0   Business Class 2025-03-01             5                    2
# 1   Business Class 2024-12-01             1                    1
# 2  Premium Economy 2025-01-01             1                    1
# 3   Business Class 2025-01-01             1                    1
# 4  Premium Economy 2025-03-01             5                    5
#
#    Ground_Service  Value_For_Money  Recommended  overall_rating  \
# 0               4                4            1               7
# 1               1                1            0               2
# 2               5                1            0               4
# 3               1                1            0               2
# 4               5                5            1              10
#
#   Departure_City Arrival_City Review_Type                 cleaned_review
# 0      Cape Town       London    Positive  disagreeable flight attendant
# 1         London       Geneva    Negative   flight delayed nearly 1 hour
# 2         London     New York    Negative                  full attitude
# 3       Chambery       London    Negative             service outrageous
# 4        Gatwick      Antigua    Positive   managed get everything right

# %% [markdown]
# ### Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    score = analyzer.polarity_scores(text)
    if score['compound'] >= 0.05:
        return "Positive"
    elif score['compound'] <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment'] = df['cleaned_review'].apply(get_sentiment)
df.head()
# Out:
#                          Review_Title Review_Date Type_of_Traveller  \
# 0     "disagreeable flight attendant"  2025-03-19      Solo Leisure
# 1  "flight was delayed nearly 1 hour"  2025-03-16          Business
# 2            "full of attitude to me"  2025-03-16          Business
# 3            "service was outrageous"  2025-03-16          Business
# 4   "managed to get everything right"  2025-03-07          Business
#
#          Seat_Type Date_Flown  Seat_Comfort  Cabin_Staff_Service  \
# 0   Business Class 2025-03-01             5                    2
# 1   Business Class 2024-12-01             1                    1
# 2  Premium Economy 2025-01-01             1                    1
# 3   Business Class 2025-01-01             1                    1
# 4  Premium Economy 2025-03-01             5                    5
#
#    Ground_Service  Value_For_Money  Recommended  overall_rating  \
# 0               4                4            1               7
# 1               1                1            0               2
# 2               5                1            0               4
# 3               1                1            0               2
# 4               5                5            1              10
#
#   Departure_City Arrival_City Review_Type                 cleaned_review  \
# 0      Cape Town       London    Positive  disagreeable flight attendant
# 1         London       Geneva    Negative   flight delayed nearly 1 hour
# 2         London     New York    Negative                  full attitude
# 3       Chambery       London    Negative             service outrageous
# 4        Gatwick      Antigua    Positive   managed get everything right
#
#   sentiment
# 0  Negative
# 1  Negative
# 2   Neutral
# 3  Negative
# 4   Neutral

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')

sns.countplot(
    x=df['sentiment'],
    palette = 'coolwarm',
    hue=df['sentiment'],
    order=df['sentiment'].value_counts().index,
    edgecolor='black'
)
for p in plt.gca().patches:
    plt.text(
        p.get_x() + p.get_width()/2,
        p.get_height() + 5,
        int(p.get_height()),
        ha='center',
        fontsize=10,
        fontweight = 'bold',
        color='black'
    )
plt.title('Sentiment Distribution of BA Reviews', fontsize=14, fontweight='bold',color='darkred')
plt.xlabel('Sentiment', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.set_style("whitegrid")

# Creating boxplot
boxplot = sns.boxplot(
    x=df['sentiment'], 
    y=df['overall_rating'],
    hue=df['sentiment'],
    palette='coolwarm', 
    width=0.6
)

# Titles and labels
plt.title('Rating Distribution Across Sentiments', fontsize=14, fontweight='bold', color='darkblue')
plt.xlabel('Sentiment', fontsize=12)
plt.ylabel('Overall Rating', fontsize=12)

plt.show()

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Neutral     352
# Negative    323
# Positive    318
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))

df['sentiment'].value_counts().plot(
    kind='pie',
    autopct="%0.1f%%",
    shadow=True,
    explode = [0.05,0.05,0.05],
    startangle=140,
    colors=['#ff9999','#66b3ff','#99ff99'],
    wedgeprops = {'edgecolor':'black'}
)
plt.title("Sentiment Distribution of Reviews", fontsize=14, fontweight='bold',color='darkblue')
plt.ylabel("")
plt.show()
